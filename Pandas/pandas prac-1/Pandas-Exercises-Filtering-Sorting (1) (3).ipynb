# %% [markdown]
# # Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset *chipotle.tsv*

# %%
chipo = pd.read_table('chipotle.tsv')

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_table('chipotle.tsv')
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?
#
# Use `str` attribute to remove the $ sign and convert the column to proper numeric type data before filtering.

# %%
chipo['item_price']=chipo['item_price'].str.replace('$','').astype(float)

# %%
chipo[chipo['item_price']>10.0].shape[0]
# Out:
# 1130

# %% [markdown]
# ### Step 5. What is the price of each item?
#
# print a data frame with only two columns `item_name` and that column which contain each `item_price`

# %%
chipo['each_item_price']= chipo['item_price']/chipo['quantity']

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values[by='item_name']
# Out:
#   Cell In[19], line 1
#     chipo.sort_values[by='item_name']
#                       ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo[chipo['each_item_price']==chipo['each_item_price'].count()]
# Out:
# Empty DataFrame
# Columns: [order_id, quantity, item_name, choice_description, item_price, each_item_price]
# Index: []

# %%
chipo['item_price'].max()

# %%
chipo['item_name'].describe()

# %%
chipo['item_name'].value_counts()

# %%
# chipo['item_name'].tolist()
chipo.groupby('item_name').count()

# %%
chipo.info()

# %% [markdown]
# ### Step 8. How many times were a Veggie Salad Bowl ordered?

# %%
chipo[chipo['item_name']=='Veggie Salad Bowl']['quantity'].sum()
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times people orderd more than one Canned Soda?

# %%
chipo[(chipo['quantity']>1)&(chipo['item_name']=='Canned Soda')].shape[0]
# Out:
# 20

# %%
chipo[('item_name']=='Canned Soda') & (chipo['quantity']>1)]
# Out:
#   Cell In[26], line 1
#     chipo[('item_name']=='Canned Soda') & (chipo['quantity']>1)]
#                       ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %% [markdown]
# # how much quantity people orders more than one Canned Sode?

# %%
chipo[(chipo['quantity']>1)&(chipo['item_name']=='Canned Soda')]['quantity'].sum()
# Out:
# 42
